# %% [markdown]
# **Executed:** Mon Oct 10 11:37:39 2016
#
# **Duration:** 4 seconds.

# %% [markdown]
# # Figure - usALEX 5 dsDNA samples FRET

# %%
from __future__ import division
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from cycler import cycler
# %matplotlib inline
# %config InlineBackend.figure_format='retina'  # for hi-dpi displays
sns.set_style('whitegrid')

palette = ('Paired', 10)
sns.palplot(sns.color_palette(*palette))
sns.set_palette(*palette)

# %% [markdown]
# ## Load Data

# %%
data_file = 'results/usALEX-5samples-E-all-methods.csv'

# %%
E = pd.read_csv(data_file, index_col=0)
E.round(2)
# Out:
#      E KDE  E Gauss  PR KDE  PR Gauss  SNA Epr mean  SNA Epr max
# 7d   92.90    92.43   92.87     92.22          91.2         93.2
# 12d  73.98    72.70   72.77     72.56          71.8         73.0
# 17d  42.68    42.26   43.14     41.98          42.4         40.9
# 22d  17.74    18.11   17.62     18.25          17.0         16.2
# 27d   8.26     8.40    7.81      7.85           6.5          6.5

# %%
E.plot.bar(table=np.round(E, 2).T)
plt.ylabel('FRET (%)')
plt.gca().xaxis.set_visible(False)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., frameon=True);
plt.legend(frameon=True);
import matplotlib
matplotlib.rcParams['svg.fonttype'] = 'none'
plt.savefig('figures/5dsDNA FRET usALEX.svg', dpi=300, bbox_inches='tight')
